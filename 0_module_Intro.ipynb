# %% [markdown]
# # Getting Started with Github and Jupyter Notebooks

# %% [markdown]
# ## Welcome!
#
# The National Institutes of Health (NIH) has multiple cloud computing programs with goals to improve access to data, modernize biomedical research, and promote equity among institutions
# <p style="color:red;font-family:arial"> However... </p>
# Many biologists and students who could <i>benefit</i> from modern programming and cloud-computing tools do not have enough background to take advantage of the resources that the NIH has commissioned and posted so that you can freely download the materials from Github ("a web-based platform that allows users to share, store and collaborate on code"). Of course, that requires that you already know what to do to access and use those materials. We would like to help you to overcome this hurdle.

# %% [markdown]
# ## Prerequisites
#
# <p style="background:blue;color:white;font-family:arial">This unit assumes that you have no experience with GitHub, Python, or even Jupyter notebooks (even though you are using a Jupyter notebook right now).</p>

# %% [markdown]
# ## Objectives
#
# The goal of this module is for you to become comfortable with the following:
# * Navigating the various material sources within GitHub repositories
# * Downloading materials from the NIH "Sandbox" (source code, bioinformatics, and datasets)
# * Creating an account on GitHub
# * Uploading materials (e.g., your own data for storage & FAIR sharing) to a GitHub repository
# * Downloading and installing Python or other similar thingies so you can run other Jupyter-notebook based tools
# * <u>Run</u> a Python program to return the complement of a DNA sequence, to demonstrate Python.

# %% [markdown]
# ## Get Started
#
# Lets get started! NEEDS A VIDEO!
#
# Open the following link in another tab: [NIH Sandbox at GitHub](https://github.com/NIGMS/NIGMS-Sandbox/blob/main/README.md)
#
# As stated in the video, GitHub is a type of cloud storage used especially by teams of coders so that they can keep track of versions of code. For <b>novice user</b> purposes, it is a way to share materials. It's just not set up to be comfortable for novice users to LOOK at and download.
#
# So, you are going to start by downloading the rest of this workshop as an example of how to use GitHub repositories.
#
# 1. Scroll down on the [page linked above at GitHub](https://github.com/NIGMS/NIGMS-Sandbox/blob/main/README.md) to find the "Available modules."
# 2. Find "Intro to Python for Bioinformatics" or use this link to get there directly.
# 3. DON'T BE (overly) INTIMIDATED. The first thing on these pages is the file structure. You can see an overview of the project, if you just scroll down.
# 4. To download materials from GitHub, you need to save a zip file of the whole folder. That download option is hidden under the "CODE" green box at the top of the main section. Click on the green "Code" box shown in this image, where we have already clicked on it to reveal the menu:
#
# ![Download Menu GitHub](https://raw.githubusercontent.com/drchase55/git_practice/refs/heads/main/github_download_pic.png)
#
# 6. Choose the "Download Zip" option at the bottom. That should save it to your local downloads folder.
# 7. Navigate to this folder & extract all the files (on Windows, double click on the folder then note the "Extract all" on the menu bar.
# 8. To view the notebook, you have several options.
# * Anaconda (use https://www.youtube.com/watch?v=WUeBzT43JyY)
# * Google Colab.research.google.com- this can call pages directly from Github, your google drive, or upload from your computer.

# %% [markdown]
# ## Conclusion
