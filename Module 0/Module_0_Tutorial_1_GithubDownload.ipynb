# %% [markdown]
# # Tutorial 1: How to download a Tutorial from the NIH Sandbox
# --------------------------------------------

# %% [markdown]
# ## Overview
# Congratulations! You have decided to make use of the fantastic NIH tutorials that are stored in the NIGMS Sandbox at the site called Github.
#
# To use these resources, you need to understand a little about "where" these files are and how to save them in a way that will let you use them to learn about the technique.
#
# The intent of this tutorial is to make sure you have clear instructions (with pictures) that will work for the most novice user.

# %% [markdown]
# ## Learning Objectives
# + Navigate the Github sandbox to find a tutorial
# + Find & read the "readme" file
# + Download a tutorial
# + Have a preliminary understanding of Github

# %% [markdown]
# ## Prerequisites
# - Knowledge of file saving & retrieving
# - An internet connection

# %% [markdown]
# ## Get Started
# Make sure that you are connected to the internet
#
# -------------------------------------------------------------

# %% [markdown]
# # Step 1: Get to the NIGMS "Sandbox" & overview

# %% [markdown]
# ## Background
# In technology and software development, a "sandbox" is a place to "play," trying out new ideas or collaborating.
#
# The National Institute of General Medical Sciences (NIGMS) is one of the NIH centers. That institute sponsored the development of many short courses (modules) to help biomedical researchers learn some of the techniques that can take advantage of the powerful options of "cloud computing."
#
# You are likely familiar with cloud data storage, for example with your files saved on OneDrive (Microsoft) or Google Drive (Google). Cloud *computing* takes that a step farther and carries out data processing and runs programs on computers that are located in some distant site.
#
# The advantage of "cloud computing" is that the computational speed and power is not limited by what you have in *your* desktop or laptop. Rather, cloud computers are very FAST computers with substantially more memory (to work on big biological data sets). Additionally, the providers of cloud computing can make more (or fewer) processors available to your job, depending on the need.

# %% [markdown]
# ## What you see when you arrive at the "Sandbox"
# It is possible that you are reading this file having already navigated to the "Sandbox."
#
# The [Sandbox](https://github.com/NIGMS/NIGMS-Sandbox) is housed at github.com. Github is a collaboration tool/website/repository that is being used by NIGMS as a "great" way to share materials.
#
# BUT, what you see when you get to github is NOT what a novice in cloud-computing-user might expect. It looks something like this picture below. It is certainly **overly complicated** for a novice because Github is not designed with novices in mind.  Thus, EVERY Github site (or "repository" of materials) looks basically the same. It shows a lot of needed tools and a list of the folders in the repository.
#
# **The key point:** scroll down ON THAT PAGE to see the nice description and information you want about the repository. It is information in the "readme" file that is displayed for you. It is just very unfortunate that unless you know to scroll past the folder structure, you start with a mysterious interface.
#
# ![image.png](attachment:d604c8a9-904d-449c-b310-61ac88e9bb13.png)

# %% [markdown]
# # Step 2: Choose a course (module) to use
# If you have scrolled down on the Sandbox readme page, you have encountered the list of available courses ("modules") that you might want to use to learn a technique.
#
# Or, perhaps you are going to use more of this module (Introduction to Github and Python for Bioinformatics).
#
# You should click on the link to that module from the list. It will take you to another "Github Repository." Of course, the interfaces will also start with the file structure as all Github repositories look the same.
#
# <div class="alert alert-block alert-warning"> <b>Attention:</b> Please go to that module in another tab on your browser before following the next set of directions</a>. </div>

# %% [markdown]
# # Step 3: Downloading the contents of the repository
#
# In order to use any of the learning modules, you will need to **download them** to open in a "cloud computing" environment. Unlike just reading a web page as you are doing now, the Sandbox tools are all constructed as special kinds of pages ("Jupyter notebooks") that combine text with interactive boxes where you will be able to write and use computer code to carry out bioinformatics functions.
#
# It is thus required that you download the whole contents of each learning module repository. Github is quite prepared for this, in fact it's one key purpose of the NIGMS using Github as a place for you to collect the materials.
#
# There isn't a normal download button that you can see. At Github, most ofthe materials are "code" that developers want to download. Thus, you will click on the green code button to get the option to download.
#
# ![<> CODE button](attachment:e70869f2-5e8c-4584-993e-048187292dd2.png)
#
# When you click on the green button you will get a menu of options. What you need is at the BOTTOM: "download zip". Select that & it will automatically start downloading to wherever your browser downloads files (e.g., your "downloads" folder on Microsoft)
# ![image.png](attachment:445327ab-4a46-491f-a907-1f0516f53f9b.png)

# %% [markdown]
# # Step 4: "Unzipping" your folder
#
# The folder of materials does not download in a ready-to-use format. It is compressed ("zipped") so needs to be "extracted" in it's full form before you upload it to use as a tutorial.
#
# <mark>To unzip a file on Windows:</mark>
#
# 1.
# Locate the zip fil (it's probably in "downloads" but you can look at this button near the top right of Chrome, for example, to see where it downloaded)
# 2. Once you find the zipped folder, r Right-click on the zip fil
# 3.
# Select "Extract All": From the context menu, choose "Extract Al (somethign like this image)
# ![image.png](attachment:06586a6d-59cc-45dc-b355-223d96404d6c.png)
# 5. .
# Choose destination: Selthe location ect where you want to extract the f (it is fine to extract them in the same folder the file is already in)
# 6. ct": Click "Extract" to start the unzipping pro
#    ss.
#
# <mark>To unzip a file on a Mac:</mark>
# 1.
# Double-click the zippe
# 2. le2.
# The file will automatically decompress and a new folder will appear in the same location as the zipped fileYou should now be ready to upload those files to run the lessons.

# %% [markdown]
# # Conclusion
# If you have followed these steps, you should now have a copy of the lessons module on your local computer. To learn how to use these lessons in a cloud computer at Amazon (AWS), [Google Cloud Computing (GCP)](https://github.com/STRIDES/NIHCloudLabGCP/blob/main/docs/vertexai.md), or Microsoft's Azure ([Azure ML](./Module_0_Tutorial_2_AzureML.ipynb)) you can use one of the linked tutorials.
#
# For the "Intro to Github and Python for Bioinformatics" module, we provide information for those using [Azure](./Module_0_Tutorial_2_AzureML.ipynb) and have tested to make sure that all the materials work as expected on Azure.

# %% [markdown]
# ## Clean up
# On most Jupyter notebooks in these modules you will see directions here to "stop your compute instance" (we'll explain later). But, since this is just a web page, you are done.
#
# Good work & we hope you enjoy learning these powerful techniques for bioinformatics!
