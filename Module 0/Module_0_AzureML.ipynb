# %% [markdown]
# # Notebooks in Azure ML
# --------------------------------------------____

# %% [markdown]
# ## Overview
# This tutorial is intended to get you started on Azure ML with a compute instance.

# %% [markdown]
# ## Learning Objectives
# + Create an Azure account
# + Start a subscription
# + Import Jupyter notebooks to Azure ML
#     - Learning Objective 2.1
#     - Learning Objective 2.2
# + Start & Stop a compute instance

# %% [markdown]
# ## Prerequisites
# - List any APIs that should be enabled.
# - List cloud platform account roles that must be assigned.
# - List necessary cloud platform access.

# %% [markdown]
# ## Get Started
# This section should outline the steps to be completed for a given module, such as:
# - Installing packages.
# - Setting up environment.
# - Establishing input and output directories.
# - Downloading and storing analysis files.
# - Running through analysis steps.
# - Outputting data and visualizations.

# %% [markdown]
# # Step 1: Create a Microsoft Azure account
# ![image.png](attachment:7c632bc6-5d54-4836-9de4-e2180770a902.png)
# To make a new Azure account, you need a

# %% [markdown]
# ## Step 2: Your subscription
# You do need a subscription to use Azure computing (required for running Python or R code).
#
# Fortunately:
# - Azure will provide the first $200 worth of charges, which is an enormous amount of computing if you are just learning and running notebooks
# - The cost is very low after that trial period is over
#
# ![image.png](attachment:6bed4a24-e7b0-4e3c-9f58-7e7b9b747d56.png)

# %% [markdown]
# ## Step 3: Opening the notebook in AzureML

# %% [markdown]
# ### Notebooks
# Azure uses their machine learning studio for jupyter notebooks. Go to [ml.azure.com](http://ml.azure.com)
#
# ![image.png](attachment:4148b5d2-173e-42d0-8e35-a9d2aa9e3a53.png)
#
# Select the notebook option.
#
# To add files, you should upload with this button:
#
# ![image.png](attachment:1694b0c8-6bcf-47e2-925c-f938924ef2b8.png)
#
# You can upload the modules that you have downloaded from github. The entire file structure will be reproduced in Azure notebooks.

# %% [markdown]
# ### Open a jupyter notebook
#
# To open tutorials, you simply click on the jupyter notebook you want to open. It will appear in the field on the right.
#
# You cannot use the Python code boxes yet! If you click on the "play" arrows nothing will happen until you start a compute instance (see next box)

# %% [markdown]
# ## Step 4: Start your compute instance
# While you can read a Jupyter notebook in AzureML, you cannot run any of the Python code without "computing." This takes additional resources so Azure makes you initiate a "compute instance."
#
# This is a tech name for a cloud workstation-- basical a computer operating through the internet.
#
# This is the key thing for which Azure will charge you, so you start it and stop it as needed.

# %% [markdown]
# ### Start the compute instance
# It is simple to start the compute intance. Above the notebook on the toolbar, there is a "play" button(right pointing triangle).
#
# ![button](attachment:0cfbedf0-52f1-4690-844d-b3c74f85b4f5.png)
#
# When you click on that, it will take about 1 minute for the cloud workstation to start up. During that time, you *can* run code boxes and the system will queue those boxes until the instance begins.

# %% [markdown]
# ### Stop the compute instance
# When you have finished with the jupyter notebook, you should **stop** the compute instance because you are being charged for the whole time it is running, whether or not you are actively using the tool.
#
# To stop this, use the stop button that is in the same spot as the start ("play") arrow. It is a square in a circle on the toolbar.
#
# ![image.png](attachment:33db4cb0-275b-4df6-8124-cc0a834fd74e.png)
#
# *Azure will turn off the compute instance if it's inactive for too long, so you are protected from accumulating excessive charges.*

# %% [markdown]
# ## Conclusion
# Provide an overview of the lessons and skills learned from the module.

# %% [markdown]
# ## Clean up
# <div class="alert alert-block alert-warning"> <b>Attention:</b> To avoid unnecessary charges, please STOP your compute instance</a>. </div>
