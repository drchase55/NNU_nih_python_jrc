# %% [markdown]
# # Submodule 4 Overview: Object oriented programming
# ---------------------------------------------------------------------------------

# %% [markdown]
# ## Overview
#
#
# ## Learning Objectives
#
# ## Prerequisites
# - Introductory Python (Module 1)
#
#
# ## Getting Started

# %% [markdown]
# ## Conclusion
#
# ### Clean up
# Be sure to stop the compute instance for your Jupyter notebooks when you are done for the day to avoid unnecesary charges.
