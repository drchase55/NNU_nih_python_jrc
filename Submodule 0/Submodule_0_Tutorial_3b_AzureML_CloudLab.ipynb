# %% [markdown]
# # Using your Cloud Credentials on AzureML
# -----------------------------------------------------------

# %% [markdown]
# ## Overview
# This mini-tutorial is designed for those using an assigned NIH Cloud Lab account on AzureML
#
# ## Learning Objectives
#
#
#
# ## Prerequisites
#
# You need to have been given a Cloud Lab account. You should have received an email with login information.
