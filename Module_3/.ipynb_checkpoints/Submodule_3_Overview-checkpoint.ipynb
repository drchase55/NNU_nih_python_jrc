# %% [markdown]
# # Overview: Foundations of Machine Learning in Python

# %% [markdown]
# # Conclusion
#
# In this lesson you learned:

# %% [markdown]
# ## Clean up
#
# Remember to shut down  your Jupyter Notebook instance when you are done to avoid unnecessary charges. You can do this by stopping the notebook instance from the **Cloud console**.
