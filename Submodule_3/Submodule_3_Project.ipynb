# %% [markdown]
# # Submodule 3: OOP Project
# ---------------------------------------------------------------------------
#
# ## Overview
#
# ## Prerequisites
# Submodule 1 (
# Submodule 2 (Numpy & Pandas)

# %% [markdown]
# ## Project description
